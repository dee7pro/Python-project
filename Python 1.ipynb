# %%
#1. Say "Hello, World!" With Python

First_string="Hello, World!"
print(First_string)
# Out:
# Hello, World!

# %%
# 2. Python If-Else

Positive_integer=int(input())
if Positive_integer % 2==1 or 6 <= Positive_integer <=20:
    print('Weird')
else:
    print('Not Weird')
# Out:
#  8
# Weird

# %%
# 3. Arithmetic Operators

a=int(input())
b=int(input())

print(f"{a+b}\n{a-b}\n{a*b}")
# Out:
#  2
#  9
# 11
# -7
# 18

# %%
# 4. Python: Division

a=int(input())
b=int(input())
print(a//b, a/b, sep='\n')
# Out:
#  1
#  9
# 0
# 0.1111111111111111

# %%
# 5. Loops

n = int(input())
for i in range (n):
    print(i**2)
# Out:
#  7
# 0
# 1
# 4
# 9
# 16
# 25
# 36

# %%
# 6. Write a function

def is_leap(year):
    leap = False
    if (year % 4 == 0):
      if (year % 100 != 0) or(year % 400 == 0):
        leap = True 
    return leap
year = int(input())
print(is_leap(year))
# Out:
#  1900
# False

# %%
# 7. Print Function

n=int(input())
for i in range(1, n+1):
    print(i, end='')
# Out:
#  9
# 123456789

# %%
# !zip my_notebook.zip Internship1.ipynb
# Out:
#   adding: Internship1.ipynb (deflated 76%)
